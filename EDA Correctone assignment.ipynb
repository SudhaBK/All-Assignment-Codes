# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %% [markdown]
# ### Task 1 : Loading data into Datframe as df and cleaning all the null values and replacing with "mean"

# %%
df = pd.read_csv("Cardiotocographic.csv")

# %%
df.fillna(df.mean(), inplace=True)

# %%
df.dropna(thresh=len(df.columns) * 0.7, inplace=True)

# %%
df.isna().sum()
# Out:
# LB          0
# AC          0
# FM          0
# UC          0
# DL          0
# DS          0
# DP          0
# ASTV        0
# MSTV        0
# ALTV        0
# MLTV        0
# Width       0
# Tendency    0
# NSP         0
# dtype: int64

# %% [markdown]
# ### Task 2: Statistical Summary

# %%
print("Statistical Summary:")
print(df.describe())
# Out:
# Statistical Summary:
#                 LB           AC           FM           UC           DL  \
# count  2126.000000  2126.000000  2126.000000  2126.000000  2126.000000
# mean    133.343598     0.003219     0.009894     0.004391     0.001895
# std      11.214328     0.004370     0.067540     0.003340     0.003343
# min      51.842487    -0.019284    -0.480634    -0.014925    -0.015393
# 25%     126.000000     0.000000     0.000000     0.001851     0.000000
# 50%     133.000000     0.001668     0.000000     0.004484     0.000000
# 75%     140.000000     0.005606     0.002567     0.006536     0.003289
# max     214.000000     0.038567     0.961268     0.030002     0.030769
#
#                 DS           DP         ASTV         MSTV         ALTV  \
# count  2126.000000  2126.000000  2126.000000  2126.000000  2126.000000
# mean      0.000003     0.000175    46.995984     1.364378    10.285964
# std       0.000141     0.000836    18.813973     1.173632    21.205041
# ...

# %%
df.describe()
# Out:
#                 LB           AC           FM           UC           DL  \
# count  2126.000000  2126.000000  2126.000000  2126.000000  2126.000000
# mean    133.343598     0.003219     0.009894     0.004391     0.001895
# std      11.214328     0.004370     0.067540     0.003340     0.003343
# min      51.842487    -0.019284    -0.480634    -0.014925    -0.015393
# 25%     126.000000     0.000000     0.000000     0.001851     0.000000
# 50%     133.000000     0.001668     0.000000     0.004484     0.000000
# 75%     140.000000     0.005606     0.002567     0.006536     0.003289
# max     214.000000     0.038567     0.961268     0.030002     0.030769
#
#                 DS           DP         ASTV         MSTV         ALTV  \
# count  2126.000000  2126.000000  2126.000000  2126.000000  2126.000000
# mean      0.000003     0.000175    46.995984     1.364378    10.285964
# std       0.000141     0.000836    18.813973     1.173632    21.205041
# ...

# %% [markdown]
# ### Task 3: Data Visualization

# %%
numerical_cols = df.select_dtypes(include=['int64', 'float64']).columns
#categorical_cols = df.select_dtypes(include=['object']).columns

# %%
for col in numerical_cols:
    plt.figure(figsize=(8,6))
    sns.histplot(df[col], kde=True)
    plt.title(f'Histogram of {col}')
    plt.show()

for col in numerical_cols:
    plt.figure(figsize=(8,6))
    sns.boxplot(df[col])
    plt.title(f'Boxplot of {col}')
    plt.show()

for col in numerical_cols:
    plt.figure(figsize=(8,6))
    sns.countplot(x=col, data=df)
    plt.title(f'Bar Chart of {col}')
    plt.show()

# %% [markdown]
# ### Task 4: Correlation Analysis

# %%
corr_matrix = df.corr()
plt.figure(figsize=(10,8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', square=True)
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# ### Task 5 Conculsion :

# %%
print("********************Conclusion:*********************")
print("******************Key Findings:*********************")
print("1. Correlations between numerical variables.")
print("2. Distribution shapes and outliers.")
print("3. Trends and patterns in temporal data.")
print( "******************Implications:*******************"  )
print("1. Informing business decisions through predictive modeling.")
print("2. Identifying areas for process improvement.")
print("3. Enhancing data quality and integrity.")
print("****************Recommendations:**********************")
print("1. Develop predictive models to forecast key variables.")
print("2. Conduct hypothesis testing to confirm correlations.")
print("3. Refine data visualization for stakeholder communication.")
# Out:
# ********************Conclusion:*********************
# ******************Key Findings:*********************
# 1. Correlations between numerical variables.
# 2. Distribution shapes and outliers.
# 3. Trends and patterns in temporal data.
# ******************Implications:*******************
# 1. Informing business decisions through predictive modeling.
# 2. Identifying areas for process improvement.
# 3. Enhancing data quality and integrity.
# ****************Recommendations:**********************
# 1. Develop predictive models to forecast key variables.
# 2. Conduct hypothesis testing to confirm correlations.
# 3. Refine data visualization for stakeholder communication.

# %% [markdown]
# ### Final Thoughts:
# This exploratory data analysis provided valuable insights, highlighting areas for further exploration and informing strategic decision-making. By leveraging these findings, stakeholders can optimize resource allocation, improve processes, and drive business growth.
